# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_csv('C:\Family Business 3\Family Business 3.csv')

# %%
df.head()
# Out:
#     Family Business  No of People Manges the Business   \
# 0  1)Fruit Gardens.                                  2
# 1    2)Grocery Shop                                  1
# 2  3)Vegetable Shop                                  1
# 3  4)Movie Theaters                                  2
# 4     5)Flower Shop                                  2
#
#   Annual income Of the Business is:                               Relation   \
# 0            Between 15 lakh-20lakh  Paternal Elder Uncle And Younger uncle
# 1                        60-80 lakh                           Elder Brother
# 2                           3 lakhs                            Elder sister
# 3                        50-70 lakh                  Paternal younger Uncle
# 4                            6lakhs                      Two younger Sister
#
#                Names                   No of Employess   \
# 0               Ram   Minimum 40-80 Part Time Employee
# 1              Vikas                                  3
# 2           Spoorthi                                  1
# 3              Shivu                                  6
# 4  Nandini & Keerthi                                  2
#
#                                Name of the Employees  \
# 0                                               …...
# 1                             1)kiran,2)Teju,3)Karan
# 2                                          1)Mounika
# 3  1)Shambu, 2)Shankar, 3)Somu, 4)Shekhar, 5)Mohi...
# 4                              1)Soumya, 2)Sangeetha
#
#   Employes Salary per Month/day
# 0                         500/D
# 1                       17000/M
# 2                        7000/M
# 3                       16000/M
# 4                        7000/M

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 8 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Family Business                    7 non-null      object
#  1   No of People Manges the Business   7 non-null      int64
#  2   Annual income Of the Business is:  7 non-null      object
#  3   Relation                           7 non-null      object
#  4   Names                              7 non-null      object
#  5   No of Employess                    7 non-null      object
#  6   Name of the Employees              7 non-null      object
#  7   Employes Salary per Month/day      7 non-null      object
# dtypes: int64(1), object(7)
# memory usage: 580.0+ bytes

# %%
df.tail()
# Out:
#     Family Business  No of People Manges the Business   \
# 2  3)Vegetable Shop                                  1
# 3  4)Movie Theaters                                  2
# 4     5)Flower Shop                                  2
# 5    6)Photo Studio                                  2
# 6    7)Car Mechanic                                  3
#
#   Annual income Of the Business is:                            Relation   \
# 2                           3 lakhs                         Elder sister
# 3                        50-70 lakh               Paternal younger Uncle
# 4                            6lakhs                   Two younger Sister
# 5                           6 lakhs                      Younger Brother
# 6                        10-12 lakh  Friends And brother(Joint Business)
#
#                  Names No of Employess   \
# 2             Spoorthi                1
# 3                Shivu                6
# 4    Nandini & Keerthi                2
# 5                Mohan                3
# 6  Anand,Arun,Abhishek                8
#
#                                Name of the Employees  \
# 2                                          1)Mounika
# 3  1)Shambu, 2)Shankar, 3)Somu, 4)Shekhar, 5)Mohi...
# 4                              1)Soumya, 2)Sangeetha
# 5                          1)David, 2)Vikram, 3)Nabi
# 6  1)Surya, 2)Chandru, 3)Hanumanthappa, 4)Advik, ...
#
#   Employes Salary per Month/day
# 2                        7000/M
# 3                       16000/M
# 4                        7000/M
# 5                        6000/M
# 6                       16500/M

# %%
data=pd.DataFrame(df)

# %%
data
# Out:
#     Family Business  No of People Manges the Business   \
# 0  1)Fruit Gardens.                                  2
# 1    2)Grocery Shop                                  1
# 2  3)Vegetable Shop                                  1
# 3  4)Movie Theaters                                  2
# 4     5)Flower Shop                                  2
# 5    6)Photo Studio                                  2
# 6    7)Car Mechanic                                  3
#
#   Annual income Of the Business is:                               Relation   \
# 0            Between 15 lakh-20lakh  Paternal Elder Uncle And Younger uncle
# 1                        60-80 lakh                           Elder Brother
# 2                           3 lakhs                            Elder sister
# 3                        50-70 lakh                  Paternal younger Uncle
# 4                            6lakhs                      Two younger Sister
# 5                           6 lakhs                         Younger Brother
# 6                        10-12 lakh     Friends And brother(Joint Business)
#
#                  Names                   No of Employess   \
# 0                 Ram   Minimum 40-80 Part Time Employee
# 1                Vikas                                  3
# 2             Spoorthi                                  1
# 3                Shivu                                  6
# 4    Nandini & Keerthi                                  2
# 5                Mohan                                  3
# 6  Anand,Arun,Abhishek                                  8
#
#                                Name of the Employees  \
# 0                                               …...
# 1                             1)kiran,2)Teju,3)Karan
# 2                                          1)Mounika
# 3  1)Shambu, 2)Shankar, 3)Somu, 4)Shekhar, 5)Mohi...
# 4                              1)Soumya, 2)Sangeetha
# 5                          1)David, 2)Vikram, 3)Nabi
# 6  1)Surya, 2)Chandru, 3)Hanumanthappa, 4)Advik, ...
#
#   Employes Salary per Month/day
# 0                         500/D
# 1                       17000/M
# 2                        7000/M
# 3                       16000/M
# 4                        7000/M
# 5                        6000/M
# 6                       16500/M

# %%
fig = plt.figure()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
x=list(data.iloc[:,0])
y=list(data.iloc[:,7])
ax.bar(x,y,color= 'b')
plt.title('Family Business Names And Employees Name')
plt.xlabel('Family Business Names')
plt.ylabel('Name of the Employees')
plt.show()

# %%
x=df['Family Business']
y=df['Employes Salary per Month/day']

# %%
plt.xlabel('Family Business', fontsize=11)
plt.ylabel('Employes Salary per Month/day', fontsize=11)
plt.bar(x,y)
# Out:
# <BarContainer object of 7 artists>

# %%
fig = plt.figure()

# %%
x=pd.array([35,25,25,15,15])
mylabels= ["Fruit","Vegetabels","grocery","Movie Theaters","Flower shop"]
myexplode= [0.2,0,0,0,0]

plt.pie(x, labels =mylabels, explode=myexplode, shadow=True)
plt.legend(title="four business:")
plt.show()

# %%
x=list(data.iloc[:,0])
y=list(data.iloc[:,7])
plt.xlabel('Family Business', fontsize=16)
plt.ylabel('Employes Salary per Month/day', fontsize=18)
plt.scatter(x, y)
#plt.plot(x, y)
plt.show()

# %%
x=list(data.iloc[:,0])
y=list(data.iloc[:,7])
plt.xlabel('Family Business', fontsize=18)
plt.ylabel('Employes Salary per Month/day', fontsize=16)
plt.scatter(x, y)
plt.plot(x, y)
plt.show()

# %%
x=list(data.iloc[:,0])
y=list(data.iloc[:,7])
plt.xlabel('Family Business', fontsize=18)
plt.ylabel('Employes Salary per Month/day', fontsize=16)
plt.plot(x, y)
plt.show()
